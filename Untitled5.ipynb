# %%
import openpyxl
import pandas as pd
import numpy as np

# %%
import_file = "./sample_auto02.xlsx"

# %%
excel_sheetname01 = "社員マスタ"
excel_sheetname02 = "予算管理表"
excel_sheetname03 = "実績管理表"
excel_sheetname04 = "実績管理表社員ID未記入"

# %%
df_employee_master = pd.read_excel(import_file, sheet_name = excel_sheetname01)
df_employee_master
# Out:
#     社員番号      氏名 所属支店 性別  Unnamed: 4
# 0   a001   辻上 明佳   東京  女     40000.0
# 1   a002   押元 大成   横浜  男     48000.0
# 2   a003  石崎 和香菜   東京  女     39000.0
# 3   a004   斉 あきの   大阪  女     43000.0
# 4   a005   寺下 春樹   札幌  男     38000.0
# 5   a006   八尾 洋志   福岡  男     28000.0
# 6   a007   関藤 梨花   札幌  女     25000.0
# 7   a008   水戸 美砂   横浜  女     41000.0
# 8   a009   小花 賢悟   横浜  男     45000.0
# 9   a010   鍵谷 一磨   福岡  男     27000.0
# 10  a011   山藤 善雄   大阪  男     40000.0
# 11  a012  辻下 万美子   東京  女     39000.0
# 12  a013   宮瀬 尚紀   福岡  男     26000.0
# 13  a014   植野 寛美   大阪  女     25000.0
# 14  a015   新森 雅紀   福岡  男     30000.0
# 15  a016  芳澤 佳乃子   横浜  女     30000.0
# 16  a017   周藤 愛乃   大阪  女     38000.0
# 17  a018   尾下 勝広   大阪  男     33000.0
# 18  a019   河路 文武   大阪  男     33000.0
# 19  a020   本廣 友広   東京  男     25000.0
# 20  a021   堀場 克巳   東京  男     29000.0
# 21  a022   安楽 遼子   札幌  女     30000.0
# 22  a023   河野 利香   大阪  女     40000.0
# 23  a024  八島 セツ子   横浜  女     44000.0
# 24  a025  伊多波 愛良   札幌  女     34000.0
# 25  a026   三角 静江   東京  女     35000.0
# 26  a027   本永 悠希   東京  女     25000.0
# 27  a028   新開 優紀   横浜  女     38000.0
# 28  a029  矢野川 昌寛   大阪  男     42000.0
# 29  a030   井熊 徹郎   横浜  男     38000.0
# 30  a031  八木沢 和貴   大阪  男     40000.0
# 31  a032   三角 和正   福岡  男     24000.0
# 32  a033  栄田 江身子   東京  女     40000.0
# 33  a034   堂園 泰典   大阪  男     31000.0
# 34  a035   泰地 生恵   横浜  女     40000.0
# 35  a036    西尾 謙   横浜  男     25000.0
# 36  a037  片尾 愛佑美   東京  女     41000.0
# 37  a038   千葉 二郎   札幌  男     41000.0
# 38  a039   吉川 紘未   大阪  男     28000.0
# 39  a040    楯 行雄   大阪  男     38000.0
# 40  a041    積 萌恵   横浜  女     38000.0
# 41  a042    池 祐矢   東京  男     29000.0
# 42  a043    今井 悠   福岡  男     35000.0
# 43  a044   一箭 姫乃   東京  女     28000.0
# 44  a045   豊竹 悦世   札幌  男     28000.0
# 45  a046    庄 佑典   福岡  男     28000.0
# 46  a047   上瀬 由和   札幌  男     28000.0
# 47  a048   蒲生 利彦   東京  男     45000.0
# 48  a049   清沢 澄枝   大阪  女     24000.0
# 49  a050   佐久田 里   札幌  女     40000.0
# 50  a051    井上 真   東京  男         NaN
# 51  a052    井上 真   東京  女         NaN

# %%
df_budget = pd.read_excel(import_file, sheet_name=excel_sheetname02)
# df_budget

# %%
df_actual = pd.read_excel(import_file, sheet_name=excel_sheetname03)
df_actual
# Out:
#            売上日  社員ID      氏名 性別  商品分類     商品名  単価（円）  数量  売上金額（円）
# 0   2020-01-04  a023   河野 利香  女  ボトムス  ロングパンツ   7000   8    56000
# 1   2020-01-05  a003  石崎 和香菜  女  ボトムス    ジーンズ   6000  10    60000
# 2   2020-01-05  a052    井上 真  女  アウター   ジャケット  10000   7    70000
# 3   2020-01-06  a003  石崎 和香菜  女  ボトムス  ロングパンツ   7000  10    70000
# 4   2020-01-07  a036    西尾 謙  男  ボトムス  ロングパンツ   7000   2    14000
# ..         ...   ...     ... ..   ...     ...    ...  ..      ...
# 219 2020-12-26  a052    井上 真  女  アウター     ダウン  18000   4    72000
# 220 2020-12-28  a036    西尾 謙  男  アウター     ダウン  18000   3    54000
# 221 2020-12-30  a003  石崎 和香菜  女  アウター     ダウン  18000   4    72000
# 222 2020-12-30  a047   上瀬 由和  男  ボトムス  ハーフパンツ   3000   3     9000
# 223 2020-12-31  a036    西尾 謙  男  ボトムス  ロングパンツ   7000  10    70000
#
# [224 rows x 9 columns]

# %%
df_actual = pd.read_excel(import_file, sheet_name=excel_sheetname03)
df_actual
# Out:
#            売上日  社員ID      氏名 性別  商品分類     商品名  単価（円）  数量  売上金額（円）
# 0   2020-01-04  a023   河野 利香  女  ボトムス  ロングパンツ   7000   8    56000
# 1   2020-01-05  a003  石崎 和香菜  女  ボトムス    ジーンズ   6000  10    60000
# 2   2020-01-05  a052    井上 真  女  アウター   ジャケット  10000   7    70000
# 3   2020-01-06  a003  石崎 和香菜  女  ボトムス  ロングパンツ   7000  10    70000
# 4   2020-01-07  a036    西尾 謙  男  ボトムス  ロングパンツ   7000   2    14000
# ..         ...   ...     ... ..   ...     ...    ...  ..      ...
# 219 2020-12-26  a052    井上 真  女  アウター     ダウン  18000   4    72000
# 220 2020-12-28  a036    西尾 謙  男  アウター     ダウン  18000   3    54000
# 221 2020-12-30  a003  石崎 和香菜  女  アウター     ダウン  18000   4    72000
# 222 2020-12-30  a047   上瀬 由和  男  ボトムス  ハーフパンツ   3000   3     9000
# 223 2020-12-31  a036    西尾 謙  男  ボトムス  ロングパンツ   7000  10    70000
#
# [224 rows x 9 columns]

# %%
pd.merge(df_employee_master, df_budget, on="社員番号").head()
# Out:
#    社員番号      氏名 所属支店 性別  Unnamed: 4   売上予算
# 0  a001   辻上 明佳   東京  女     40000.0  40000
# 1  a002   押元 大成   横浜  男     48000.0  48000
# 2  a003  石崎 和香菜   東京  女     39000.0  39000
# 3  a004   斉 あきの   大阪  女     43000.0  43000
# 4  a005   寺下 春樹   札幌  男     38000.0  38000

# %%
pd.merge(df_employee_master, df_actual, left_on="社員番号", right_on="社員ID").head()
# Out:
#    社員番号    氏名_x 所属支店 性別_x  Unnamed: 4        売上日  社員ID    氏名_y 性別_y  商品分類  \
# 0  a003  石崎 和香菜   東京    女     39000.0 2020-01-05  a003  石崎 和香菜    女  ボトムス
# 1  a003  石崎 和香菜   東京    女     39000.0 2020-01-06  a003  石崎 和香菜    女  ボトムス
# 2  a003  石崎 和香菜   東京    女     39000.0 2020-01-19  a003  石崎 和香菜    女  トップス
# 3  a003  石崎 和香菜   東京    女     39000.0 2020-01-21  a003  石崎 和香菜    女  アウター
# 4  a003  石崎 和香菜   東京    女     39000.0 2020-01-24  a003  石崎 和香菜    女  ボトムス
#
#       商品名  単価（円）  数量  売上金額（円）
# 0    ジーンズ   6000  10    60000
# 1  ロングパンツ   7000  10    70000
# 2     シャツ   4000   1     4000
# 3     ダウン  18000   1    18000
# 4  ロングパンツ   7000   6    42000

# %%
pd.merge(df_employee_master, df_actual, left_on=["氏名","性別"],right_on=["氏名","性別"]).head()
# Out:
#    社員番号      氏名 所属支店 性別  Unnamed: 4        売上日  社員ID  商品分類     商品名  単価（円）  数量  \
# 0  a003  石崎 和香菜   東京  女     39000.0 2020-01-05  a003  ボトムス    ジーンズ   6000  10
# 1  a003  石崎 和香菜   東京  女     39000.0 2020-01-06  a003  ボトムス  ロングパンツ   7000  10
# 2  a003  石崎 和香菜   東京  女     39000.0 2020-01-19  a003  トップス     シャツ   4000   1
# 3  a003  石崎 和香菜   東京  女     39000.0 2020-01-21  a003  アウター     ダウン  18000   1
# 4  a003  石崎 和香菜   東京  女     39000.0 2020-01-24  a003  ボトムス  ロングパンツ   7000   6
#
#    売上金額（円）
# 0    60000
# 1    70000
# 2     4000
# 3    18000
# 4    42000

# %%
df_employee_actual = pd.merge(df_employee_master, df_actual, left_on="社員番号", right_on="社員ID")

# %%
df_employee_actual
# Out:
#      社員番号    氏名_x 所属支店 性別_x  Unnamed: 4        売上日  社員ID    氏名_y 性別_y  商品分類  \
# 0    a003  石崎 和香菜   東京    女     39000.0 2020-01-05  a003  石崎 和香菜    女  ボトムス
# 1    a003  石崎 和香菜   東京    女     39000.0 2020-01-06  a003  石崎 和香菜    女  ボトムス
# 2    a003  石崎 和香菜   東京    女     39000.0 2020-01-19  a003  石崎 和香菜    女  トップス
# 3    a003  石崎 和香菜   東京    女     39000.0 2020-01-21  a003  石崎 和香菜    女  アウター
# 4    a003  石崎 和香菜   東京    女     39000.0 2020-01-24  a003  石崎 和香菜    女  ボトムス
# ..    ...     ...  ...  ...         ...        ...   ...     ...  ...   ...
# 219  a052    井上 真   東京    女         NaN 2020-08-25  a052    井上 真    女  トップス
# 220  a052    井上 真   東京    女         NaN 2020-09-01  a052    井上 真    女  ボトムス
# 221  a052    井上 真   東京    女         NaN 2020-09-11  a052    井上 真    女  トップス
# 222  a052    井上 真   東京    女         NaN 2020-11-10  a052    井上 真    女  トップス
# 223  a052    井上 真   東京    女         NaN 2020-12-26  a052    井上 真    女  アウター
#
#         商品名  単価（円）  数量  売上金額（円）
# 0      ジーンズ   6000  10    60000
# 1    ロングパンツ   7000  10    70000
# 2       シャツ   4000   1     4000
# 3       ダウン  18000   1    18000
# 4    ロングパンツ   7000   6    42000
# ..      ...    ...  ..      ...
# 219     シャツ   4000   5    20000
# 220  ロングパンツ   7000   5    35000
# 221     シャツ   4000   2     8000
# 222     シャツ   4000   2     8000
# 223     ダウン  18000   4    72000
#
# [224 rows x 14 columns]

# %%
df_employee_actual = df_employee_actual.drop(["氏名_y","性別_y", "社員ID"], axis=1)

# %%
# df_employee_actual

# %%
df_employee_actual = df_employee_actual.rename(columns={"氏名_x":"氏名","性別_x":"性別"})

# %%
df_employee_actual
# Out:
#      社員番号      氏名 所属支店 性別  Unnamed: 4        売上日  商品分類     商品名  単価（円）  数量  \
# 0    a003  石崎 和香菜   東京  女     39000.0 2020-01-05  ボトムス    ジーンズ   6000  10
# 1    a003  石崎 和香菜   東京  女     39000.0 2020-01-06  ボトムス  ロングパンツ   7000  10
# 2    a003  石崎 和香菜   東京  女     39000.0 2020-01-19  トップス     シャツ   4000   1
# 3    a003  石崎 和香菜   東京  女     39000.0 2020-01-21  アウター     ダウン  18000   1
# 4    a003  石崎 和香菜   東京  女     39000.0 2020-01-24  ボトムス  ロングパンツ   7000   6
# ..    ...     ...  ... ..         ...        ...   ...     ...    ...  ..
# 219  a052    井上 真   東京  女         NaN 2020-08-25  トップス     シャツ   4000   5
# 220  a052    井上 真   東京  女         NaN 2020-09-01  ボトムス  ロングパンツ   7000   5
# 221  a052    井上 真   東京  女         NaN 2020-09-11  トップス     シャツ   4000   2
# 222  a052    井上 真   東京  女         NaN 2020-11-10  トップス     シャツ   4000   2
# 223  a052    井上 真   東京  女         NaN 2020-12-26  アウター     ダウン  18000   4
#
#      売上金額（円）
# 0      60000
# 1      70000
# 2       4000
# 3      18000
# 4      42000
# ..       ...
# 219    20000
# 220    35000
# 221     8000
# 222     8000
# 223    72000
#
# [224 rows x 11 columns]

# %%
df_employee_actual.pivot_table(index="所属支店",columns="商品分類",values="売上金額（円）", aggfunc="sum")
# Out:
# 商品分類     アウター    トップス     ボトムス
# 所属支店
# 大阪     918000  424000   458000
# 札幌     636000  296000   416000
# 東京    1582000  764000  1059000
# 横浜     786000  292000   361000
# 福岡     464000  340000   883000

# %%
df_employee_actual.pivot_table(index="所属支店", columns="商品分類", values="売上金額（円）", aggfunc="mean")
# Out:
# 商品分類           アウター          トップス          ボトムス
# 所属支店
# 大阪     76500.000000  35333.333333  26941.176471
# 札幌    106000.000000  42285.714286  29714.285714
# 東京     65916.666667  33217.391304  29416.666667
# 横浜     78600.000000  26545.454545  27769.230769
# 福岡     77333.333333  42500.000000  35320.000000

# %%
df_employee_actual.pivot_table(index="所属支店", columns="商品分類", values="売上金額（円）", aggfunc="mean").astype("int")
# Out:
# 商品分類    アウター   トップス   ボトムス
# 所属支店
# 大阪     76500  35333  26941
# 札幌    106000  42285  29714
# 東京     65916  33217  29416
# 横浜     78600  26545  27769
# 福岡     77333  42500  35320

# %%
df_employee_actual.pivot_table(index="所属支店", columns="商品分類", values="売上金額（円）", aggfunc="count")
# Out:
# 商品分類  アウター  トップス  ボトムス
# 所属支店
# 大阪      12    12    17
# 札幌       6     7    14
# 東京      24    23    36
# 横浜      10    11    13
# 福岡       6     8    25

# %%
df_employee_actual.pivot_table(index="所属支店", columns="商品分類", values="売上金額（円）", aggfunc=np.std).astype("int")
df_employee_actual.pivot_table(index="所属支店", columns="商品分類", values="売上金額（円）", aggfunc=np.median).astype("int")
df_employee_actual.pivot_table(index="所属支店", columns="商品分類", values="売上金額（円）", aggfunc=[np.mean, np.median]).astype("int")
# Out:
#         mean                median
# 商品分類    アウター   トップス   ボトムス    アウター   トップス   ボトムス
# 所属支店
# 大阪     76500  35333  26941   70000  32000  24000
# 札幌    106000  42285  29714  108000  40000  27500
# 東京     65916  33217  29416   65000  28000  27500
# 横浜     78600  26545  27769   62000  24000  18000
# 福岡     77333  42500  35320   71000  40000  36000

# %%
df_employee_actual.pivot_table(index="氏名", columns="商品分類", values="売上金額（円）", aggfunc=lambda x: np.sum(x)*1.10).astype("int")
# Out:
# 商品分類       アウター    トップス    ボトムス
# 氏名
# 上瀬 由和    699600  325600  457600
# 井上 真     616000  220000  193600
# 宮瀬 尚紀    510400  374000  971300
# 河野 利香   1009800  466400  503800
# 石崎 和香菜  1124200  620400  971300
# 西尾 謙     864600  321200  397100

# %%
df_actual[["氏名","売上金額（円）"]].groupby("氏名").sum()
# Out:
#         売上金額（円）
# 氏名
# 上瀬 由和   1348000
# 井上 真     936000
# 宮瀬 尚紀   1687000
# 河野 利香   1800000
# 石崎 和香菜  2469000
# 西尾 謙    1439000

# %%
df_actual["売上日"]>="2020-04-01"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 219     True
# 220     True
# 221     True
# 222     True
# 223     True
# Name: 売上日, Length: 224, dtype: bool

# %%
df_actual["売上日"]<"2020-07-01"
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 219    False
# 220    False
# 221    False
# 222    False
# 223    False
# Name: 売上日, Length: 224, dtype: bool

# %%
(df_actual["売上日"]>="2020-04-01") & (df_actual["売上日"]<"2020-07-01")
df_actual[(df_actual["売上日"]>="2020-04-01") & (df_actual["売上日"]<"2020-07-01")]
# Out:
#           売上日  社員ID      氏名 性別  商品分類     商品名  単価（円）  数量  売上金額（円）
# 50 2020-04-03  a003  石崎 和香菜  女  ボトムス  ロングパンツ   7000   3    21000
# 51 2020-04-04  a047   上瀬 由和  男  トップス     ニット   8000   8    64000
# 52 2020-04-09  a003  石崎 和香菜  女  ボトムス  ロングパンツ   7000   8    56000
# 53 2020-04-09  a023   河野 利香  女  トップス     ニット   8000  10    80000
# 54 2020-04-11  a003  石崎 和香菜  女  ボトムス  ロングパンツ   7000   3    21000
# 55 2020-04-14  a003  石崎 和香菜  女  ボトムス    ジーンズ   6000   4    24000
# 56 2020-04-15  a036    西尾 謙  男  アウター   ジャケット  10000   3    30000
# 57 2020-04-18  a003  石崎 和香菜  女  トップス     ニット   8000   1     8000
# 58 2020-04-18  a051    井上 真  男  ボトムス  ロングパンツ   7000   5    35000
# 59 2020-04-19  a003  石崎 和香菜  女  トップス     ニット   8000   6    48000
# 60 2020-04-20  a036    西尾 謙  男  トップス     ニット   8000   3    24000
# 61 2020-04-21  a013   宮瀬 尚紀  男  アウター   ジャケット  10000   7    70000
# 62 2020-04-24  a023   河野 利香  女  ボトムス    ジーンズ   6000   4    24000
# 63 2020-04-29  a023   河野 利香  女  ボトムス    ジーンズ   6000   1     6000
# 64 2020-05-05  a047   上瀬 由和  男  トップス     シャツ   4000  10    40000
# 65 2020-05-06  a013   宮瀬 尚紀  男  ボトムス    ジーンズ   6000   5    30000
# 66 2020-05-12  a003  石崎 和香菜  女  アウター   ジャケット  10000   6    60000
# 67 2020-05-13  a023   河野 利香  女  トップス     ニット   8000   6    48000
# 68 2020-05-14  a036    西尾 謙  男  アウター   ジャケット  10000  10   100000
# 69 2020-05-15  a003  石崎 和香菜  女  ボトムス  ロングパンツ   7000   6    42000
# 70 2020-05-20  a036    西尾 謙  男  ボトムス  ロングパンツ   7000   1     7000
# 71 2020-05-22  a023   河野 利香  女  トップス     ニット   8000  10    80000
# 72 2020-05-24  a003  石崎 和香菜  女  トップス     シャツ   4000   7    28000
# 73 2020-05-24  a003  石崎 和香菜  女  ボトムス    ジーンズ   6000   5    30000
# 74 2020-05-24  a047   上瀬 由和  男  ボトムス  ハーフパンツ   3000   6    18000
# 75 2020-05-25  a023   河野 利香  女  アウター     ダウン  18000   4    72000
# 76 2020-06-02  a013   宮瀬 尚紀  男  ボトムス    ジーンズ   6000   7    42000
# 77 2020-06-02  a051    井上 真  男  ボトムス    ジーンズ   6000   8    48000
# 78 2020-06-03  a023   河野 利香  女  トップス     ニット   8000   4    32000
# 79 2020-06-03  a047   上瀬 由和  男  アウター   ジャケット  10000   6    60000
# 80 2020-06-08  a003  石崎 和香菜  女  ボトムス  ロングパンツ   7000   7    49000
# 81 2020-06-10  a023   河野 利香  女  トップス     シャツ   4000   1     4000
# 82 2020-06-11  a023   河野 利香  女  アウター     ダウン  18000   9   162000
# 83 2020-06-13  a036    西尾 謙  男  ボトムス  ロングパンツ   7000   2    14000
# 84 2020-06-14  a003  石崎 和香菜  女  トップス     ニット   8000   8    64000
# 85 2020-06-15  a023   河野 利香  女  ボトムス    ジーンズ   6000   5    30000
# 86 2020-06-15  a036    西尾 謙  男  トップス     ニット   8000   2    16000
# 87 2020-06-16  a003  石崎 和香菜  女  トップス     ニット   8000   5    40000
# 88 2020-06-16  a047   上瀬 由和  男  ボトムス  ロングパンツ   7000   6    42000
# 89 2020-06-17  a036    西尾 謙  男  トップス     ニット   8000   5    40000
# 90 2020-06-18  a013   宮瀬 尚紀  男  ボトムス    ジーンズ   6000  10    60000
# 91 2020-06-22  a003  石崎 和香菜  女  トップス     ニット   8000   8    64000
# 92 2020-06-25  a013   宮瀬 尚紀  男  ボトムス  ハーフパンツ   3000   2     6000
# 93 2020-06-26  a036    西尾 謙  男  ボトムス    ジーンズ   6000  10    60000
# 94 2020-06-27  a023   河野 利香  女  アウター   ジャケット  10000   2    20000
# 95 2020-06-27  a052    井上 真  女  トップス     シャツ   4000   5    20000
# 96 2020-06-30  a003  石崎 和香菜  女  ボトムス  ハーフパンツ   3000   7    21000
# 97 2020-06-30  a052    井上 真  女  トップス     ニット   8000   8    64000

# %%
df_actual[["氏名","商品分類","売上金額（円）"]].groupby(["氏名","商品分類"]).sum()
# Out:
#              売上金額（円）
# 氏名     商品分類
# 上瀬 由和  アウター   636000
#        トップス   296000
#        ボトムス   416000
# 井上 真   アウター   560000
#        トップス   200000
#        ボトムス   176000
# 宮瀬 尚紀  アウター   464000
#        トップス   340000
#        ボトムス   883000
# 河野 利香  アウター   918000
#        トップス   424000
#        ボトムス   458000
# 石崎 和香菜 アウター  1022000
#        トップス   564000
#        ボトムス   883000
# 西尾 謙   アウター   786000
#        トップス   292000
#        ボトムス   361000

# %%
df_actual[["氏名","商品分類","売上金額（円）"]].groupby(["氏名","商品分類"]).mean()
# Out:
#                    売上金額（円）
# 氏名     商品分類
# 上瀬 由和  アウター  106000.000000
#        トップス   42285.714286
#        ボトムス   29714.285714
# 井上 真   アウター   70000.000000
#        トップス   25000.000000
#        ボトムス   22000.000000
# 宮瀬 尚紀  アウター   77333.333333
#        トップス   42500.000000
#        ボトムス   35320.000000
# 河野 利香  アウター   76500.000000
#        トップス   35333.333333
#        ボトムス   26941.176471
# 石崎 和香菜 アウター   63875.000000
#        トップス   37600.000000
#        ボトムス   31535.714286
# 西尾 謙   アウター   78600.000000
#        トップス   26545.454545
#        ボトムス   27769.230769

# %%
df_actual[["氏名","商品分類","売上金額（円）"]].groupby(["氏名","商品分類"]).max()
# Out:
#              売上金額（円）
# 氏名     商品分類
# 上瀬 由和  アウター   144000
#        トップス    80000
#        ボトムス    63000
# 井上 真   アウター   144000
#        トップス    64000
#        ボトムス    48000
# 宮瀬 尚紀  アウター   162000
#        トップス    80000
#        ボトムス    70000
# 河野 利香  アウター   162000
#        トップス    80000
#        ボトムス    63000
# 石崎 和香菜 アウター   180000
#        トップス    64000
#        ボトムス    70000
# 西尾 謙   アウター   180000
#        トップス    56000
#        ボトムス    70000

# %%
df_actual[["氏名","商品分類","売上金額（円）"]].groupby(["氏名","商品分類"]).min()
# Out:
#              売上金額（円）
# 氏名     商品分類
# 上瀬 由和  アウター    60000
#        トップス     4000
#        ボトムス     7000
# 井上 真   アウター    10000
#        トップス     8000
#        ボトムス     3000
# 宮瀬 尚紀  アウター    20000
#        トップス    16000
#        ボトムス     3000
# 河野 利香  アウター    10000
#        トップス     4000
#        ボトムス     6000
# 石崎 和香菜 アウター    10000
#        トップス     4000
#        ボトムス     3000
# 西尾 謙   アウター    10000
#        トップス     4000
#        ボトムス     6000

# %%
df_actual[["氏名","商品分類","売上金額（円）"]].groupby(["氏名","商品分類"]).count()
# Out:
#              売上金額（円）
# 氏名     商品分類
# 上瀬 由和  アウター        6
#        トップス        7
#        ボトムス       14
# 井上 真   アウター        8
#        トップス        8
#        ボトムス        8
# 宮瀬 尚紀  アウター        6
#        トップス        8
#        ボトムス       25
# 河野 利香  アウター       12
#        トップス       12
#        ボトムス       17
# 石崎 和香菜 アウター       16
#        トップス       15
#        ボトムス       28
# 西尾 謙   アウター       10
#        トップス       11
#        ボトムス       13

# %%
# !pip install sns
# Out:
# Collecting sns
#   Downloading sns-0.1.tar.gz (2.1 kB)
# Building wheels for collected packages: sns
#   Building wheel for sns (setup.py) ... done
#   Created wheel for sns: filename=sns-0.1-py3-none-any.whl size=2661 sha256=3b07e9311564161e8c93d380c2accf25b469ae51551cac459c64a1f57a2e9646
#   Stored in directory: /Users/kageyama/Library/Caches/pip/wheels/ff/12/fa/4d724fdfed493cfe12b239ae9a0bc26b2fd85bb7dc9ecde7c3
# Successfully built sns
# Installing collected packages: sns
# Successfully installed sns-0.1

# %%
df_sales_pivot=df_employee_actual.pivot_table(index="所属支店",columns="商品分類",values="売上金額（円）",aggfunc="sum")

# %%
df_sales_pivot.head()
# Out:
# 商品分類     アウター    トップス     ボトムス
# 所属支店
# 大阪     918000  424000   458000
# 札幌     636000  296000   416000
# 東京    1582000  764000  1059000
# 横浜     786000  292000   361000
# 福岡     464000  340000   883000

# %%
df_sales_pivot.index=["osaka","sapporo","tokyo","yokohama","fukuoka"]
df_sales_pivot.columns=["outer","tops","bottoms"]

# %%
df_sales_pivot
# Out:
#             outer    tops  bottoms
# osaka      918000  424000   458000
# sapporo    636000  296000   416000
# tokyo     1582000  764000  1059000
# yokohama   786000  292000   361000
# fukuoka    464000  340000   883000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))

x = df_sales_pivot.index
y = df_sales_pivot["outer"]
sns.barplot(x, y, palette="rocket")
# Out:
# /Users/kageyama/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='outer'>

# %%
sns.heatmap(df_sales_pivot)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(7,7))

# %%
sns.set_palette("Set2")
plt.pie(df_sales_pivot["outer"], labels=df_sales_pivot.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb6e82ebac0>,
#   <matplotlib.patches.Wedge at 0x7fb6e82ebfd0>,
#   <matplotlib.patches.Wedge at 0x7fb7285a2550>,
#   <matplotlib.patches.Wedge at 0x7fb7285a2a60>,
#   <matplotlib.patches.Wedge at 0x7fb7285a2f40>],
#  [Text(0.8706461467870358, 0.6722910731854822, 'osaka'),
#   Text(-0.21836522561952143, 1.0781078926712928, 'sapporo'),
#   Text(-1.0740249963032433, -0.23763481924124283, 'tokyo'),
#   Text(0.3700456051114613, -1.0358891109272712, 'yokohama'),
#   Text(1.0398050833339842, -0.35889467629487937, 'fukuoka')])

# %%
plt.figure(figsize=(7,7))
sns.set_palette("Set2")
plt.pie(df_sales_pivot["outer"], labels=df_sales_pivot.index)
plt.savefig("graph.png", dpi=200)
